# %% [markdown]
# ## 1). Given a string - 'Today is a sunny day'
#
# #### a). Write a code to extract the words 'Today and ‘sunny'
#
# #### b). Obtain the last 2 letters - 'ay'
#
# #### c). Write the statement backwards

# %%
text="Today is a sunny Day" 
a=text[0:5]
b=text[11:16]
a+ ' '+ b
# Out:
# 'Today sunny'

# %%
text[-2:]
# Out:
# 'ay'

# %%
text[::-1]
# Out:
# 'yaD ynnus a si yadoT'

# %% [markdown]
# ## 2). Concatenate the variables num = 34 and string ='How old are you?'  using '+' operator.

# %%
num=34
co=str(num)+"How old are you?"
co
# Out:
# '34How old are you?'

# %%
Input1 = input()
print(input1)
# Out:
# 123456
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4992/2174618694.py in <module>
#       1 Input1 = input()
# ----> 2 print(input1)
#
# NameError: name 'input1' is not defined
