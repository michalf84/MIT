# %% [markdown]
# ### 1. Write a program to print the integer and string given, take the input from the user.

# %% [markdown]
# #### Integer = 22
# #### String = 'Great Learning'

# %%
a=input("Give Integer")
b=input("give string")
print(str(a),b)
# Out:
# Give Integer22
# give stringGreat Learning
# 22 Great Learning

# %% [markdown]
# ### 2. Write a program that takes age, name and gender of the user as input

# %%
age=int(input("give age:"))
name=input("give name:")
# Out:
# give age:( 14 % 2 ) * ( 9 // 4 ) + 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7416/1844224477.py in <module>
# ----> 1 age=int(input("give age:"))
#       2 name=input("give name:")
#
# ValueError: invalid literal for int() with base 10: '( 14 % 2 ) * ( 9 // 4 ) + 4'

# %%
a="some tezxt"
a[7:5:-1]
# Out:
# 'ze'
